# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashmari/Tweets_analyze/blob/Ashmari-patch-1/seperate_personal_emotional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load CSV file into a DataFrame
df = pd.read_excel('/content/translated_data_processed.xlsx',header=1)

# %%
df
# Out:
#                                               sentences  \
# 0               六本木なう(*･ω･)ﾉwithスンちゃん、ちえ☆ [USER] [USER]
# 1     [USER] 私初段からやばくてなっちゃんにのんでもらってた!!なっちゃんごめん大丈夫?まあ...
# 2     [USER] さん 僕のほぼメインのヨーヨーは フェノム プロト ジェネシス＋  LOOP9...
# 3     今から、娘と、みなとみらいホールへ、“楽器ものしりコンサート”に行きます。 久々に少しオシャ...
# 4                      大塚ばりキモい(笑)  食い物ねだってくる(>_<) さすがでぶ
# ...                                                 ...
# 9995  お願いですからメアド教えてください！光陵中学の酒匂巧です！(^^)メアドosaka_yaba...
# 9996  [USER] 冗談が過ぎましたかねぇ(￣▽￣;) ごめんなさい！実際に開いてたらちゃんと教え...
# 9997  小腹を満たして鹿児島へ。今日は食事会。トンボ帰りやだな。 (@ モスバーガー 都城大学通り店...
# 9998                   [USER] [USER] [USER] おやすみありですぅ><
# 9999  [USER] おひさぁ〜、お元気でしてかぁ？見つけてしまいました。挨拶しないではおられまい！...
#
#                                              translated
# 0     Now in Roppongi (*･ω･)ﾉ with Sun-chan and Chie...
# 1     [ASSISTANT] I was in a bad state from the begi...
# 2     [USER], my main yoyos are mostly the Phenom Pr...
# 3     I'm going with my daughter to the Minato Mirai...
# ...

# %%
# Clean and preprocess the Twitter data (you can customize this part based on your cleaning requirements)
# Example: Remove special characters, URLs, and unwanted columns
df['cleaned_text'] = twitter_df['text'].str.replace(r'http\S+|www.\S+|[^a-zA-Z\s]', '', regex=True)
df = twitter_df[['cleaned_text', 'user', 'created_at']]

# %%
# Filter sentences containing 'I' or 'me'
#filtered_df = df[df['sentence'].str.contains(r'\bI\b|\bme\b', case=False, regex=True)]
# Filter sentences containing 'I' or 'me' in the 'Translated' column
personal_filtered_df = df[df['translated'].str.contains(r'\b(?:I|me|my)\b', case=False, na=False)]
df['translated'].fillna('', inplace=True)
# Filter sentences not containing 'I' or 'me'
common_df = df[~df['translated'].str.contains(r'\b(?:I|me|my)\b', case=False, regex=True)]

# %%
personal_filtered_df['cleaned_text'] = personal_filtered_df['translated'].str.replace(r'http\S+|www.\S+|[^a-zA-Z\s]', '', regex=True)
# Out:
# <ipython-input-18-7bfb9aead61f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   personal_filtered_df['cleaned_text'] = personal_filtered_df['translated'].str.replace(r'http\S+|www.\S+|[^a-zA-Z\s]', '', regex=True)

# %%
personal_filtered_df
# Out:
#                                               sentences  \
# 1     [USER] 私初段からやばくてなっちゃんにのんでもらってた!!なっちゃんごめん大丈夫?まあ...
# 2     [USER] さん 僕のほぼメインのヨーヨーは フェノム プロト ジェネシス＋  LOOP9...
# 3     今から、娘と、みなとみらいホールへ、“楽器ものしりコンサート”に行きます。 久々に少しオシャ...
# 6     busy？ or not busy？ I could not understand toda...
# 8      今日の収穫：珍宝島が実在して、その領有権をめぐって、中ソ間で武力衝突があったということを知った。
# ...                                                 ...
# 9994          この時間帯まじソフトバンク繋がらん。アンテナ立っててもパケットが殆ど落ちて来ない。
# 9995  お願いですからメアド教えてください！光陵中学の酒匂巧です！(^^)メアドosaka_yaba...
# 9996  [USER] 冗談が過ぎましたかねぇ(￣▽￣;) ごめんなさい！実際に開いてたらちゃんと教え...
# 9997  小腹を満たして鹿児島へ。今日は食事会。トンボ帰りやだな。 (@ モスバーガー 都城大学通り店...
# 9999  [USER] おひさぁ〜、お元気でしてかぁ？見つけてしまいました。挨拶しないではおられまい！...
#
#                                              translated  \
# 1     [ASSISTANT] I was in a bad state from the begi...
# 2     [USER], my main yoyos are mostly the Phenom Pr...
# 3     I'm going with my daughter to the Minato Mirai...
# 6     Are you busy? I couldn't understand today's wo...
# ...

# %%
common_df['cleaned_text'] = common_df['translated'].str.replace(r'http\S+|www.\S+|[^a-zA-Z\s]', '', regex=True)
# Out:
# <ipython-input-21-f59292c47f79>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   common_df['cleaned_text'] = common_df['translated'].str.replace(r'http\S+|www.\S+|[^a-zA-Z\s]', '', regex=True)

# %%
common_df
# Out:
#                                               sentences  \
# 0               六本木なう(*･ω･)ﾉwithスンちゃん、ちえ☆ [USER] [USER]
# 4                      大塚ばりキモい(笑)  食い物ねだってくる(>_<) さすがでぶ
# 5                     [USER] 10件目から帰署(；´Д`A忙しいバイ♪(´ε｀ )
# 7     [USER] おおおぉぉ‼ご近所♪( ´▽｀) よろしく〜( ´ ▽ ` )ﾉ ヨークベニマ...
# 12         千葉交通京成バス 東京駅八重洲口前バス停(銚子・佐原・TDR方面)にタッチ！ [URL]
# ...                                                 ...
# 9988  今日は金曜日！！ 博多デイトス「焼鳥司」はたくさんのお客さんを今日もお待ちしておりますm(_...
# 9990                 [USER] もしかして俺たちの見ていたiganuは幻だったのか…？
# 9991         ♫  @ Starbucks Coffee 仙台泉パークタウン タピオ店 [URL]
# 9993              仙台で初の1人ラーメン♡ (@ らーめん ぶぅ) [pic]: [URL]
# 9998                   [USER] [USER] [USER] おやすみありですぅ><
#
#                                              translated  \
# 0     Now in Roppongi (*･ω･)ﾉ with Sun-chan and Chie...
# 4     Otsuka is so gross (lol). Always begging for f...
# 5     [ASSISTANT] Returning to the police station fr...
# 7     [USER] Ohhh! Hello, neighbor♪ ( ´▽｀) Nice to m...
# ...

# %%
# Save filtered DataFrames to separate CSV files
personal_filtered_df.to_csv('personal_filtered_sentences.csv', index=False)
common_df.to_csv('common_sentences.csv', index=False)
